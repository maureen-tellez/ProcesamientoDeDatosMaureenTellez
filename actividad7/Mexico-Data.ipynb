# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Cargar datos
df = pd.read_stata('Mexico-2023-full-data.dta')

# %%
#Determinanen la cantidad de filas y columnas 
df.shape
# Out:
# (1322, 357)

# %%
#Mostrar tabla
df.head()
# Out:
#      idstd  id             a4a     a6a           a2            a1c  \
# 0  1164932   3  Other Services  Medium        South  Establishment
# 1  1164933  14        Garments   Small  Mexico City  Establishment
# 2  1164934  16            Food   Large        North  Establishment
# 3  1164935  17            Food       4        North  Establishment
# 4  1164936  18            Food   Small  Mexico City  Establishment
#
#    competition_select  tax_select vat_applicable  \
# 0                   0           0            Yes
# 1                   0           1            Yes
# 2                   1           0            Yes
# 3                   0           1            Yes
# 4                   1           0            Yes
#
#                                         a4b_v4  ... d1a2_v4  \
# 0                                     Textiles  ...    1394
# 1            Construction (Section F: (41-43))  ...    4290
# 2                Leather and related products   ...    3100
# 3                Leather and related products   ...    1071
# 4  Printing and reproduction of recorded media  ...    1811
#
#   stratificationregioncode stratificationsizecode  stratificationsectorcode  \
# 0                    South         Medium (20-99)            Other Services
# 1              Mexico City           Small (5-19)                  Garments
# 2                    North                      6                      Food
# 3                    North                      6                      Food
# 4              Mexico City           Small (5-19)                      Food
#
#   stratificationpanelcode     wstrict      wmedian        wweak  strata  a12
# 0                   Panel  637.467224  1238.401855  1367.814331     223  2.0
# 1                   Panel   32.484642    49.580254    65.690323     157  1.0
# 2                   Panel   19.873146    12.904718    19.949972      50  NaN
# 3                   Panel   19.873146    12.904718    19.949972      50  NaN
# 4                   Panel    1.784358     1.114933     1.493892     154  1.0
#
# [5 rows x 357 columns]
