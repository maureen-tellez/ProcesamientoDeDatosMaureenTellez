# %%
import pandas as pd
import numpy as np

# Cargar datos
df = pd.read_stata('Mexico-2023-full-data.dta')

display(df_modelo.head())
# Cuenta cuántos datos faltan en cada columna
columnas_finales = ['d2', 'l1', 'b5', 'l10', 'n2a', 'd3c']
df_modelo = df[columnas_finales].copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       4 # Cargar datos
#       5 df = pd.read_stata('Mexico-2023-full-data.dta')
# ----> 7 display(df_modelo.head())
#       8 # Cuenta cuántos datos faltan en cada columna
#      10 columnas_finales = ['d2', 'l1', 'b5', 'l10', 'n2a', 'd3c']
#
# NameError: name 'df_modelo' is not defined
