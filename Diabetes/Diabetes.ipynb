# %% [markdown]
# # #Diabetes ejercicio

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split

# %%
# Cargamos datos 
data = load_diabetes()
X_all = data.data
y_all = data.target

# %%
#entrenamos el modelo
X, y = load_diabetes(return_X_y=True)
X = X[:, [2]]  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=20, shuffle=False)

# %%
regressor = LinearRegression().fit(X_train, y_train)
y_pred = regressor.predict(X_test)

print(f"Mean squared error: {mean_squared_error(y_test, y_pred):.2f}")
print(f"Coefficient of determination: {r2_score(y_test, y_pred):.2f}")
# Out:
# Mean squared error: 2548.07
# Coefficient of determination: 0.47

# %%
fig, ax = plt.subplots(ncols=2, figsize=(10, 5), sharex=True, sharey=True)

ax[0].scatter(X_train, y_train, label="Train data points")
ax[0].plot(
    X_train,
    regressor.predict(X_train),
    linewidth=3,
    color="tab:orange",
    label="Model predictions",
)
ax[0].set(xlabel="Feature", ylabel="Target", title="Train set")
ax[0].legend()

ax[1].scatter(X_test, y_test, label="Test data points")
ax[1].plot(X_test, y_pred, linewidth=3, color="tab:orange", label="Model predictions")
ax[1].set(xlabel="Feature", ylabel="Target", title="Test set")
ax[1].legend()

fig.suptitle("Linear Regression")

plt.show()

# %% [markdown]
# # #Conclusión

# %% [markdown]
# Se está probando la relación entre el índice de masa corporal (IMC) y la progresión de la diabetes. Primero se utilizó el conjunto de datos proporcionado por scikit-learn, verificando la información disponible para trabajar correctamente con los datos.
# Al final, los resultados muestran que el IMC sí tiene una relación con la progresión de la enfermedad, aunque no es completamente determinante. El coeficiente de determinación indica qué tanto el modelo logra explicar el comportamiento de la progresión de la diabetes a partir del IMC. En este caso, su valor refleja que el IMC explica solo una parte de la variación, lo que sugiere que existen otros factores importantes que influyen en la enfermedad y que no están siendo considerados en este modelo.
