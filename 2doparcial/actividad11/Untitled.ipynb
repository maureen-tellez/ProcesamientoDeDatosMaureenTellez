# %%
# !pip install tensorflow-datasets
# Out:
# Requirement already satisfied: tensorflow-datasets in /opt/anaconda3/envs/tf311/lib/python3.11/site-packages (4.9.9)
# Requirement already satisfied: absl-py in /opt/anaconda3/envs/tf311/lib/python3.11/site-packages (from tensorflow-datasets) (2.4.0)
# Requirement already satisfied: dm-tree in /opt/anaconda3/envs/tf311/lib/python3.11/site-packages (from tensorflow-datasets) (0.1.9)
# Requirement already satisfied: etils>=1.9.1 in /opt/anaconda3/envs/tf311/lib/python3.11/site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (1.14.0)
# Requirement already satisfied: immutabledict in /opt/anaconda3/envs/tf311/lib/python3.11/site-packages (from tensorflow-datasets) (4.3.1)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/tf311/lib/python3.11/site-packages (from tensorflow-datasets) (1.26.4)
# Requirement already satisfied: promise in /opt/anaconda3/envs/tf311/lib/python3.11/site-packages (from tensorflow-datasets) (2.3)
# Requirement already satisfied: protobuf>=3.20 in /opt/anaconda3/envs/tf311/lib/python3.11/site-packages (from tensorflow-datasets) (4.25.8)
# Requirement already satisfied: psutil in /opt/anaconda3/envs/tf311/lib/python3.11/site-packages (from tensorflow-datasets) (7.2.2)
# Requirement already satisfied: pyarrow in /opt/anaconda3/envs/tf311/lib/python3.11/site-packages (from tensorflow-datasets) (23.0.1)
# Requirement already satisfied: requests>=2.19.0 in /opt/anaconda3/envs/tf311/lib/python3.11/site-packages (from tensorflow-datasets) (2.32.5)
# Requirement already satisfied: simple_parsing in /opt/anaconda3/envs/tf311/lib/python3.11/site-packages (from tensorflow-datasets) (0.1.8)
# Requirement already satisfied: tensorflow-metadata in /opt/anaconda3/envs/tf311/lib/python3.11/site-packages (from tensorflow-datasets) (1.17.3)
# Requirement already satisfied: termcolor in /opt/anaconda3/envs/tf311/lib/python3.11/site-packages (from tensorflow-datasets) (3.3.0)
# Requirement already satisfied: toml in /opt/anaconda3/envs/tf311/lib/python3.11/site-packages (from tensorflow-datasets) (0.10.2)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/tf311/lib/python3.11/site-packages (from tensorflow-datasets) (4.67.3)
# Requirement already satisfied: wrapt in /opt/anaconda3/envs/tf311/lib/python3.11/site-packages (from tensorflow-datasets) (2.1.1)
# Requirement already satisfied: einops in /opt/anaconda3/envs/tf311/lib/python3.11/site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (0.8.2)
# Requirement already satisfied: fsspec in /opt/anaconda3/envs/tf311/lib/python3.11/site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (2026.2.0)
# Requirement already satisfied: typing_extensions in /opt/anaconda3/envs/tf311/lib/python3.11/site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (4.15.0)
# Requirement already satisfied: zipp in /opt/anaconda3/envs/tf311/lib/python3.11/site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/tf311/lib/python3.11/site-packages (from requests>=2.19.0->tensorflow-datasets) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/tf311/lib/python3.11/site-packages (from requests>=2.19.0->tensorflow-datasets) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/tf311/lib/python3.11/site-packages (from requests>=2.19.0->tensorflow-datasets) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/tf311/lib/python3.11/site-packages (from requests>=2.19.0->tensorflow-datasets) (2026.2.25)
# Requirement already satisfied: attrs>=18.2.0 in /opt/anaconda3/envs/tf311/lib/python3.11/site-packages (from dm-tree->tensorflow-datasets) (25.4.0)
# Requirement already satisfied: six in /opt/anaconda3/envs/tf311/lib/python3.11/site-packages (from promise->tensorflow-datasets) (1.17.0)
# Requirement already satisfied: docstring-parser~=0.15 in /opt/anaconda3/envs/tf311/lib/python3.11/site-packages (from simple_parsing->tensorflow-datasets) (0.17.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.56.4 in /opt/anaconda3/envs/tf311/lib/python3.11/site-packages (from tensorflow-metadata->tensorflow-datasets) (1.73.0)

# %%
import sys
print(sys.executable)
# Out:
# /opt/anaconda3/envs/py311/bin/python

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import math
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import tensorflow as tf
# ----> 2 import tensorflow_datasets as tfds
#       3 import matplotlib.pyplot as plt
#       4 import math
#
# ModuleNotFoundError: No module named 'tensorflow_datasets'
