# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

#librerias para operaciones de regresi´n lineal 
from sklearn import linear_model
from sklearn.metrics import mean_squared_error,r2_score

# %%
data = pd.read_csv(r"/Users/maureentellez/Documents/Universidad/8semestre/procesamiento/archivo.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data = pd.read_csv(r"/Users/maureentellez/Documents/Universidad/8semestre/procesamiento/archivo.csv")
#
# NameError: name 'pd' is not defined

# %%
#Determinanen la cantidad de filas y columnas

# %%
data.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data.shape
#
# NameError: name 'data' is not defined

# %%
#Determinar la canto
